# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('/content/placement.csv')

# %%
print("Dataset Shape:", df.shape)
print(df.head())
# Out:
# Dataset Shape: (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
plt.title("CGPA vs Resume Score")
plt.show()

# %%
X = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values

# %%
p = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
p.fit(X, y)
# Out:
# Perceptron(random_state=42)

# %%
print("Model Coefficients (Weights):", p.coef_)
print("Model Intercept (Bias):", p.intercept_)
# Out:
# Model Coefficients (Weights): [[ 45.99 -37.99]]
# Model Intercept (Bias): [-48.]

# %%
plt.figure(figsize=(7, 5))
plot_decision_regions(X, y, clf=p, legend=2)
plt.xlabel("CGPA")
plt.ylabel("Resume Score")
plt.title("Perceptron Decision Boundary")
plt.show()
